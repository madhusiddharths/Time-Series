# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
register_matplotlib_converters()
from time import time

# %%
def parser(s):
    return datetime.strptime(s, '%Y-%m-%d')

# %%
catfish_sales = pd.read_csv('catfish.csv', parse_dates=[0], index_col=0, date_parser=parser)
catfish_sales.head()
# Out:
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Temp\ipykernel_19304\1792076116.py:1: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   catfish_sales = pd.read_csv('catfish.csv', parse_dates=[0], index_col=0, date_parser=parser)
#             Total
# Date
# 1986-01-01   9034
# 1986-02-01   9596
# 1986-03-01  10558
# 1986-04-01   9002
# 1986-05-01   9239

# %%
catfish_sales = catfish_sales.asfreq(pd.infer_freq(catfish_sales.index))

# %%
start_date = datetime(1996,1,1)
end_date = datetime(2000,1,1)
lim_catfish_sales = catfish_sales[start_date:end_date]

# %%
plt.figure(figsize=(10,4))
plt.plot(lim_catfish_sales)
plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Sales', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
first_diff = lim_catfish_sales.diff()[1:]
first_diff
# Out:
#              Total
# Date
# 1996-02-01   291.0
# 1996-03-01  2091.0
# 1996-04-01 -2428.0
# 1996-05-01   393.0
# 1996-06-01 -2595.0
# 1996-07-01   645.0
# 1996-08-01  1498.0
# 1996-09-01  -575.0
# 1996-10-01  1200.0
# 1996-11-01 -2638.0
# 1996-12-01 -1306.0
# 1997-01-01  3848.0
# 1997-02-01  2312.0
# 1997-03-01  1566.0
# 1997-04-01 -2470.0
# 1997-05-01   290.0
# 1997-06-01  -973.0
# 1997-07-01   395.0
# 1997-08-01   682.0
# 1997-09-01 -1030.0
# 1997-10-01  1890.0
# 1997-11-01 -3763.0
# 1997-12-01 -1367.0
# 1998-01-01  5298.0
# 1998-02-01  3074.0
# 1998-03-01  -443.0
# 1998-04-01 -3012.0
# 1998-05-01  -235.0
# 1998-06-01    42.0
# 1998-07-01   -29.0
# 1998-08-01  1116.0
# 1998-09-01 -1284.0
# 1998-10-01   436.0
# 1998-11-01 -1660.0
# 1998-12-01  -462.0
# 1999-01-01  1988.0
# 1999-02-01  2673.0
# 1999-03-01  2764.0
# 1999-04-01 -5056.0
# 1999-05-01   476.0
# 1999-06-01  -244.0
# 1999-07-01  1349.0
# 1999-08-01  -451.0
# 1999-09-01  -188.0
# 1999-10-01   799.0
# 1999-11-01 -2885.0
# 1999-12-01    28.0
# 2000-01-01  3040.0

# %%
plt.figure(figsize=(10,4))
plt.plot(first_diff)
plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Sales', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)
plt.axhline(0, color='k', linestyle='--', alpha=0.2)

# %%
acf_vals = acf(first_diff)
num_lags = 17
plt.bar(range(num_lags), acf_vals[:num_lags])
# Out:
# <BarContainer object of 17 artists>

# %%
pacf_vals = pacf(first_diff)
num_lags = 15
plt.bar(range(num_lags), pacf_vals[:num_lags])
# Out:
# <BarContainer object of 15 artists>

# %%
train_end = datetime(1999,7,1)
test_end = datetime(2000,1,1)

train_data = lim_catfish_sales[:train_end]
test_data = lim_catfish_sales[train_end + timedelta(days=1):test_end]

# %%
my_order = (0,1,0)
my_seasonal_order = (1, 0, 1, 12)
# define model
model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)

# %%
start = time()
model_fit = model.fit()
end = time()
print('Model Fitting Time:', end - start)
# Out:
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Model Fitting Time: 0.48632383346557617

# %%
print(model_fit.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                Total   No. Observations:                   43
# Model:             SARIMAX(0, 1, 0)x(1, 0, [1], 12)   Log Likelihood                -365.635
# Date:                              Sun, 13 Aug 2023   AIC                            737.269
# Time:                                      17:23:54   BIC                            742.482
# Sample:                                  01-01-1996   HQIC                           739.180
#                                        - 07-01-1999
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.8250      0.120      6.848      0.000       0.589       1.061
# ma.S.L12      -0.5187      0.197     -2.632      0.008      -0.905      -0.132
# sigma2       1.78e+06    4.7e+05      3.791      0.000     8.6e+05     2.7e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.82   Jarque-Bera (JB):                 1.13
# Prob(Q):                              0.09   Prob(JB):                         0.57
# Heteroskedasticity (H):               0.81   Skew:                            -0.30
# Prob(H) (two-sided):                  0.70   Kurtosis:                         2.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predictions = model_fit.forecast(len(test_data))
predictions = pd.Series(predictions, index=test_data.index)
predictions
# Out:
# Date
# 1999-08-01    25695.472898
# 1999-09-01    25054.187808
# 1999-10-01    25642.853739
# 1999-11-01    24195.599159
# 1999-12-01    23677.351442
# 2000-01-01    26250.585291
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
test_data
# Out:
#             Total
# Date
# 1999-08-01  24618
# 1999-09-01  24430
# 1999-10-01  25229
# 1999-11-01  22344
# 1999-12-01  22372
# 2000-01-01  25412

# %%
residuals = []
t1 = test_data.values
t2 = predictions.values
for i in range(len(t1)):
    residuals.append(t1[i] - t2[i])
residuals
# Out:
# [array([-1077.47289769]),
#  array([-624.1878084]),
#  array([-413.85373882]),
#  array([-1851.59915885]),
#  array([-1305.35144196]),
#  array([-838.58529141])]

# %%
plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
plt.figure(figsize=(10,4))

plt.plot(lim_catfish_sales)
plt.plot(predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Production', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
residuals = np.array(residuals)
residuals
# Out:
# array([[-1077.47289769],
#        [ -624.1878084 ],
#        [ -413.85373882],
#        [-1851.59915885],
#        [-1305.35144196],
#        [ -838.58529141]])

# %%
print('Mean Absolute Percent Error:', round(np.mean(abs(residuals/test_data)),4))
# Out:
# Mean Absolute Percent Error: 0.0433

# %%
print('Root Mean Squared Error:', np.sqrt(np.mean(residuals**2)))
# Out:
# Root Mean Squared Error: 1122.3056851564268

# %%
rolling_predictions = test_data.copy()
for train_end in test_data.index:
    train_data = lim_catfish_sales[:train_end-timedelta(days=1)]
    model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
    model_fit = model.fit()

    pred = model_fit.forecast()
    rolling_predictions[train_end] = pred
# Out:
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\MADHU SIDDHARTH S\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'

# %%
rolling_residuals = []
n = 0
for i in rolling_predictions.index:
    rolling_residuals.append(test_data.values[n] - sum(rolling_predictions[i].fillna(0)))
    n += 1
rolling_residuals
# Out:
# [array([-1077.47289769]),
#  array([451.80703149]),
#  array([223.1829562]),
#  array([-1385.20363978]),
#  array([572.58019438]),
#  array([317.4216021])]

# %%
plt.figure(figsize=(10,4))
plt.plot(rolling_residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Rolling Forecast Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
plt.figure(figsize=(10,4))

plt.plot(lim_catfish_sales)
plt.plot(rolling_predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Catfish Sales in 1000s of Pounds', fontsize=20)
plt.ylabel('Production', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
rolling_residuals = np.array(rolling_residuals)
print('Mean Absolute Percent Error:', round(np.mean(abs(rolling_residuals/test_data)),4))
# Out:
# Mean Absolute Percent Error: 0.0285

# %%
print('Root Mean Squared Error:', np.sqrt(np.mean(rolling_residuals**2)))
# Out:
# Root Mean Squared Error: 791.8629665785995
